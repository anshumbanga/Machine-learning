# %%
# importing major libraries 

import pandas as pd
import seaborn as sns 
import numpy as np 
import matplotlib.pyplot as plt 
import plotly.express as px 

# additional libraries 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('CO2.csv')

# %%
df.head() # overview
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
plt.figure(figsize=(12,3))
sns.scatterplot(data=df,x='Volume',y='CO2')
plt.title('Volume vs Carbon Emission')
plt.show()

# %%
plt.figure(figsize=(12,3))
sns.scatterplot(data=df,x='Weight',y='CO2')
plt.title('Weight vs Carbon Emission')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
px.scatter_3d(df,x='Volume',y='Weight',z='CO2',
              title='Carbon Emission',color='CO2',
              height=500)

# %%
# scikit 

from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression

# %%
x = df[['Volume','Weight']]
y = df.CO2

# %%
x.head()
y.head()
# Out:
# 0     99
# 1     95
# 2     95
# 3     90
# 4    105
# Name: CO2, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print('Rows for training\t',x_train.shape[0])
print('Rows for testing\t',x_test.shape[0])
# Out:
# Rows for training	 28
# Rows for testing	 8

# %%
# underfit --> poort training, poor testing 
# lack of data

# %%
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print('w1:',lr.coef_[0],',w2:',lr.coef_[1])
print('bias:',lr.intercept_)

# m1x1 + m2x2 + c
# Out:
# w1: 0.00428741424907569 ,w2: 0.008049279585677116
# bias: 84.21502006695282

# %%
y_pred = lr.predict(x_test)

# %%
y_pred

from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.32941109624012765
